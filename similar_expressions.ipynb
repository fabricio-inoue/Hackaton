# %%
from gensim.models import Word2Vec
from itertools import combinations
import re

# Lista de expressões
expressions = ["inocência presumida", "falsa confissão", "conflito armado", "conflitos armados", "conflito civil", "conflitos civis", "guerra", "conflito", "democracia", "Convenção de Genebra", "tratado", "paz", "manutenção da paz", "corrupção", "instituição", "funcionário público", "governo", "suborno", "crime", "crimes", "criminoso", "déficit democrático", "democratização", "institucional", "tomada de decisão", "sociedade", "política", "ajuda financeira", "conflito étnico", "conflitos étnicos", "exoneração", "genocídio", "homicídio", "assassinato", "tráfico humano", "sistema de justiça criminal", "sistema de justiça", "justiça arbitrária", "refugiado", "terrorista", "violência", "tortura", "estado de direito efetivo", "fluxo de armas", "instituição transparente", "instituições transparentes", "boa governança", "identidade legal para todos", "liberdade de informação", "instituição de direitos humanos", "ativistas de direitos humanos", "liberdade fundamental", "liberdades fundamentais", "conflito violento", "conflitos violentos", "sociedade pacífica", "instituição efetiva", "instituições eficazes", "instituição responsável", "instituições responsáveis", "instituição inclusiva", "instituições inclusivas", "abuso infantil", "detenção arbitrária", "detenção sem sentença", "sistema judicial", "tribunal criminal", "sociedade inclusiva", "sociedades inclusivas", "instituição responsiva", "instituições responsivas", "sociedade justa", "sociedades justas", "recurso/remédio legal", "recursos/remédios legais", "independência do judiciário", "judiciário independente", "separação de poderes", "extremismo", "crime de guerra", "crime organizado", "transferência ilícita", "dinheiro ilícito", "tráfico de armas", "cibercrime / crime/s cibernético/s", "insurgência", "instituição democrática", "instabilidade política", "tomada de decisão política", "Convenção de Aarhus", "liberdade de imprensa", "liberdade de expressão"]

# Pré-processamento dos dados
expressions_processed = [re.sub(r'[^\w\s]', '', exp.lower()).split() for exp in expressions]

# Treinamento do modelo Word2Vec
model = Word2Vec(expressions_processed, vector_size=100, window=5, min_count=1, workers=4)

# Geração de expressões semelhantes
similar_expressions = []

for exp in expressions_processed:
    similar_words = set()
    for word in exp:
        similar_words.update([similar_word[0] for similar_word in model.wv.most_similar(word)])
    similar_expressions.append(similar_words)

# Impressão das expressões semelhantes
for i, exp in enumerate(similar_expressions):
    if i < 20:
        print(f"Expressão original: {expressions[i]}")
        print("Expressões semelhantes:")
        for similar_exp in combinations(exp, len(exp)):
            print(" ".join(similar_exp))
        print()
# Out:
# Expressão original: inocência presumida
# Expressões semelhantes:
# cibercrime de recursoremédio crime para funcionário manutenção inclusiva sistema tráfico violento do étnico sociedades ajuda efetivo democracia crimes suborno
#
# Expressão original: falsa confissão
# Expressões semelhantes:
# criminoso fundamentais étnicos estado crime justiça infantil manutenção arbitrária responsáveis étnico tratado expressão todos independência liberdades transparente instituições civil humano
#
# Expressão original: conflito armado
# Expressões semelhantes:
# efetiva fluxo estado crime paz justiça financeira justa direitos assassinato governo tratado dinheiro liberdade cibernéticos institucional ilícita responsiva armados identidade
#
# Expressão original: conflitos armados
# Expressões semelhantes:
# sociedade democrática terrorista ilícito separação justiça recursosremédios poderes tomada armado tortura direitos liberdades responsiva déficit insurgência judicial corrupção humano
#
# Expressão original: conflito civil
# Expressões semelhantes:
# institucional criminoso confissão justiça boa responsiva efetiva étnicos tratado dinheiro financeira direito liberdade fluxo armado ilícito direitos ativistas
#
# Expressão original: conflitos civis
# Expressões semelhantes:
# cibercrime violência democrática legais terrorista genebra separação recursosremédios poderes responsivas direitos assassinato tribunal liberdades transparente responsiva déficit insurgência judicial
#
# Expressão original: guerra
# Expressões semelhantes:
# independente separação judiciário funcionário boa sociedade sem estado ilícito genebra
#
# Expressão original: conflito
# Expressões semelhantes:
# institucional justiça responsiva efetiva tratado dinheiro financeira liberdade fluxo direitos
#
# Expressão original: democracia
# Expressões semelhantes:
# étnico convenção tratado inocência crimes déficit homicídio arbitrária corrupção tortura
#
# Expressão original: Convenção de Genebra
# Expressões semelhantes:
# independente presumida guerra recursoremédio terrorista crime separação manutenção inclusiva exoneração tomada arbitrária democratização direitos instituição étnico sem independência institucional ajuda transparente efetivo sentença democracia democrático crimes instabilidade
#
# Expressão original: tratado
# Expressões semelhantes:
# confissão justiça judiciário pacífica étnicos democracia criminal armados arbitrária conflito
#
# Expressão original: paz
# Expressões semelhantes:
# organizado justiça cibercrime ilícita instituição governo expressão imprensa terrorista armado
#
# Expressão original: manutenção da paz
# Expressões semelhantes:
# organizado cibercrime de efetiva inocência terrorista fluxo crime justiça inclusiva armado do responsáveis instituição eficazes governo étnico tratado inclusivas falsa expressão tribunal ilícita crimes imprensa suborno judicial
#
# Expressão original: corrupção
# Expressões semelhantes:
# para recursosremédios violência efetiva democracia tomada identidade armados política ilícito
#
# Expressão original: instituição
# Expressões semelhantes:
# paz poderes efetivo sociedades crimes todos identidade legal genebra independência
#
# Expressão original: funcionário público
# Expressões semelhantes:
# guerra organizado inocência aarhus democrática recursoremédio ilícito armas para transparentes transferência sociedades sem inclusivas cibernéticos legal todos responsiva crimes justas
#
# Expressão original: governo
# Expressões semelhantes:
# paz justiça manutenção responsiva sociedades violentos abuso judicial armado direitos
#
# Expressão original: suborno
# Expressões semelhantes:
# violência manutenção inclusiva responsiva inocência instabilidade terrorista estado política justa
#
# Expressão original: crime
# Expressões semelhantes:
# presumida fundamental manutenção de responsáveis efetivo falsa estado violento ilícito
#
# Expressão original: crimes
# Expressões semelhantes:
# ajuda presumida público cibercrime violência manutenção instituição étnico conflito genebra
